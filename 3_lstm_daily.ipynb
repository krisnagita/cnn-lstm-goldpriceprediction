# %% [markdown]
# # **Gold Price Prediction Using CNN-LSTM**

# %% [markdown]
# ## Import and Install Library

# %%
# !pip install -q keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from google.colab import drive

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, TimeDistributed, Conv1D
from tensorflow.python.keras.layers.pooling import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Flatten

import random as python_random

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

import datetime

# %% [markdown]
# ## Load Dataset

# %%
#Mount to google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/TugasAkhir/Code/"

# %%
data = pd.read_excel("/content/drive/MyDrive/TugasAkhir/Code/Dataset/1-daily.xlsx")

# %%
data.head()
# Out:
#         Date  Prices
# 0 1978-12-29  226.00
# 1 1979-01-01  226.00
# 2 1979-01-02  226.80
# 3 1979-01-03  218.60
# 4 1979-01-04  223.15

# %%
data.tail()
# Out:
#             Date   Prices
# 11016 2021-03-22  1736.15
# 11017 2021-03-23  1726.20
# 11018 2021-03-24  1730.50
# 11019 2021-03-25  1737.30
# 11020 2021-03-26  1731.80

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11021 entries, 0 to 11020
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    11021 non-null  datetime64[ns]
#  1   Prices  11021 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 172.3 KB

# %% [markdown]
# ## Pre-Processing

# %%
#Check the pattern of dataset

plt.figure(figsize=(20,10))
plt.plot(data['Date'], data['Prices'])
plt.title("Data Prices Gold Daily 1980 - 2020 ", fontsize=16)
plt.ylabel("Prices", fontsize=14)
plt.xlabel("Years", fontsize=14)
plt.show()

# %%
#Filter Data
data = data[(data['Date'] >= pd.Timestamp(2005,3,26)) & (data['Date'] <= pd.Timestamp(2021,3,26))]

# %%
#Check the pattern of dataset after filter

plt.figure(figsize=(20,10))
plt.plot(data['Date'], data['Prices'])
plt.title("Data Prices Gold Daily 2005 - 2020 ", fontsize=16)
plt.ylabel("Prices", fontsize=14)
plt.xlabel("Years", fontsize=14)
plt.show()

# %%
#Check the types of all atributes
data.dtypes
# Out:
# Date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4175 entries, 6846 to 11020
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4175 non-null   datetime64[ns]
#  1   Prices  4175 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 97.9 KB

# %% [markdown]
# ### Check

# %%
#Split into Data Train and Data Test (80:20)
train_size = int(len(data) * 0.80)
test_size = (int(len(data) - train_size))

#Data training
data_train = data[0:train_size]

#Data testing
data_test = data[train_size:len(data)]

print("The amount of data train: ", len(data_train))
print("The amount of data train: ", len(data_test))
# Out:
# The amount of data train:  3340
# The amount of data train:  835

# %%
#Check missing values in data train
data_train.isnull().sum()
# Out:
# Date      0
# Prices    0
# dtype: int64

# %%
#Check missing values in data test
data_test.isnull().sum()
# Out:
# Date      0
# Prices    0
# dtype: int64

# %%
#Make data train into numpy array
arr_price_train = data_train['Prices'].to_numpy()
# arr_date_train = data_train['Date'].to_numpy()

#Make data test into numpy array
arr_price_test = data_test['Prices'].to_numpy()
# arr_date_test = data_test['Date'].to_numpy()

# %%
scalerMinMax = MinMaxScaler()
# scalerStandard = StandardScaler() 

#Normalize the data train
scaled_data_train = scalerMinMax.fit_transform(arr_price_train.reshape(-1,1))

#Normalize the data test
scaled_data_test = scalerMinMax.fit_transform(arr_price_test.reshape(-1,1))

# %%
#Checking the normalize result
for i in range(len(scaled_data_train)):
    if (i <= 5):
        print(scaled_data_train[i])
# Out:
# [0.00722704]
# [0.0078687]
# [0.0081051]
# [0.00881429]
# [0.00857789]
# [0.00638276]

# %% [markdown]
# The first step is to split the input sequences into subsequences that can be processed by the CNN model. For example, we can first split our univariate time series data into input/output samples with four steps as input and one as output. Each sample can then be split into two sub-samples, each with two time steps. The CNN can interpret each subsequence of two time steps and provide a time series of interpretations of the subsequences to the LSTM model to process as input.
#
# We can parameterize this and define the number of subsequences as n_seq and the number of time steps per subsequence as n_steps. The input data can then be reshaped to have the required structure

# %%
#Split a univariate sequence into samples
def splitSequences(data, n_steps):
    x, y = list(),list()
    for i in range(len(data)):
        #Find the end of this pattern
        end = i + n_steps
        #Check if we are beyond the sequence
        if end > len(data)-1:
            break
        #Gather input and outputs part of the pattern
        seq_x, seq_y = data[i:end], data[end]
        x.append(seq_x)
        y.append(seq_y)
    return x, y

# %%
#Scaled data train became the input sequence
input_seq_train = scaled_data_train

#Scaled data test became the input sequence
input_seq_test = scaled_data_test

# %%
#Choose a number of time steps (In this case time steps = 1)

n_steps = 4
train_X, train_y = splitSequences(input_seq_train, n_steps)
test_X, test_y = splitSequences(input_seq_test, n_steps)

print("The amount of data train: ", len(train_X))
print("The amount of data train: ", len(test_X))
# Out:
# The amount of data train:  3336
# The amount of data train:  831

# %%
#Make data into numpy array

train_X = np.asarray(train_X)
train_y = np.asarray(train_y)

test_X = np.asarray(test_X)
test_y = np.asarray(test_y)

# %%
#Reshape from [samples, timesteps] into[samples, subsequence, timesteps, features]
n_features = 1
n_steps = 4

# #Reshape for data train
train_X = train_X.reshape((train_X.shape[0], train_X.shape[1], n_features))

#Reshape for data test
test_X = test_X.reshape((test_X.shape[0],test_X.shape[1], n_features))

# %% [markdown]
# ## Building Model

# %% [markdown]
# ![cnn-lstm fix.png](data:image/png;base64,...)

# %%
#Not get random result

np.random.seed(123)
python_random.seed(123)
tf.random.set_seed(12345)

# %%
# Define Model CNN-LSTM

model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_steps, n_features), return_sequences=True))
model.add(LSTM(100, activation='relu'))
# model.add(Dropout(0.1))
model.add(Dense(1, activation="relu")) # Output Layer
model.compile(optimizer='Adam', loss='mean_squared_error')

earlyStop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 100)            40800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training Model

# %%
#Training Model
model_train = model.fit(train_X, train_y, validation_split=0.33, epochs=1000, batch_size=256, verbose=1, callbacks=[earlyStop])
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 5s 55ms/step - loss: 0.2424 - val_loss: 0.2248
# Epoch 2/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 0.1641 - val_loss: 0.1104
# Epoch 3/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0620 - val_loss: 0.0012
# Epoch 4/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0234 - val_loss: 0.0033
# Epoch 5/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0119 - val_loss: 0.0075
# Epoch 6/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0058 - val_loss: 6.8260e-04
# Epoch 7/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 8/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0010 - val_loss: 2.3947e-04
# Epoch 9/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 6.8513e-04 - val_loss: 2.9987e-04
# Epoch 10/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 4.5023e-04 - val_loss: 2.8133e-04
# Epoch 11/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 3.4555e-04 - val_loss: 1.1741e-04
# Epoch 12/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.7858e-04 - val_loss: 1.3094e-04
# Epoch 13/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 2.4929e-04 - val_loss: 1.2319e-04
# Epoch 14/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.4120e-04 - val_loss: 1.1778e-04
# Epoch 15/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.4044e-04 - val_loss: 1.2235e-04
# Epoch 16/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.3716e-04 - val_loss: 1.1799e-04
# Epoch 17/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.3492e-04 - val_loss: 1.1743e-04
# Epoch 18/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.3401e-04 - val_loss: 1.1692e-04
# Epoch 19/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.3289e-04 - val_loss: 1.1809e-04
# Epoch 20/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.3265e-04 - val_loss: 1.1748e-04
# Epoch 21/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.3198e-04 - val_loss: 1.1523e-04
# Epoch 22/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.3051e-04 - val_loss: 1.1609e-04
# Epoch 23/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2953e-04 - val_loss: 1.1672e-04
# Epoch 24/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.2898e-04 - val_loss: 1.1742e-04
# Epoch 25/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2732e-04 - val_loss: 1.1602e-04
# Epoch 26/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2712e-04 - val_loss: 1.1569e-04
# Epoch 27/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2637e-04 - val_loss: 1.1509e-04
# Epoch 28/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2714e-04 - val_loss: 1.2790e-04
# Epoch 29/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.2855e-04 - val_loss: 1.2964e-04
# Epoch 30/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2649e-04 - val_loss: 1.1865e-04
# Epoch 31/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2567e-04 - val_loss: 1.1570e-04
# Epoch 32/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2453e-04 - val_loss: 1.1912e-04
# Epoch 33/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2446e-04 - val_loss: 1.3144e-04
# Epoch 34/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2510e-04 - val_loss: 1.1747e-04
# Epoch 35/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.2348e-04 - val_loss: 1.1511e-04
# Epoch 36/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2877e-04 - val_loss: 1.1386e-04
# Epoch 37/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2514e-04 - val_loss: 1.1577e-04
# Epoch 38/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2590e-04 - val_loss: 1.2176e-04
# Epoch 39/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.2465e-04 - val_loss: 1.2000e-04
# Epoch 40/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2353e-04 - val_loss: 1.2658e-04
# Epoch 41/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2496e-04 - val_loss: 1.3230e-04
# Epoch 42/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.2272e-04 - val_loss: 1.2893e-04
# Epoch 43/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2498e-04 - val_loss: 1.3440e-04
# Epoch 44/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2366e-04 - val_loss: 1.3095e-04
# Epoch 45/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2271e-04 - val_loss: 1.5428e-04
# Epoch 46/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2963e-04 - val_loss: 1.3276e-04
# Epoch 47/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 2.2060e-04 - val_loss: 1.2755e-04
# Epoch 48/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 2.2228e-04 - val_loss: 1.3499e-04
# Epoch 49/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2436e-04 - val_loss: 1.2336e-04
# Epoch 50/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 2.2064e-04 - val_loss: 1.1989e-04
# Epoch 51/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2220e-04 - val_loss: 1.1743e-04
# Epoch 52/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1988e-04 - val_loss: 1.1592e-04
# Epoch 53/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 2.1971e-04 - val_loss: 1.1737e-04
# Epoch 54/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1951e-04 - val_loss: 1.3695e-04
# Epoch 55/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2329e-04 - val_loss: 1.2537e-04
# Epoch 56/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1808e-04 - val_loss: 1.3723e-04
# Epoch 57/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2231e-04 - val_loss: 1.4151e-04
# Epoch 58/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.2177e-04 - val_loss: 1.3449e-04
# Epoch 59/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1849e-04 - val_loss: 1.5061e-04
# Epoch 60/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2192e-04 - val_loss: 1.3981e-04
# Epoch 61/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2066e-04 - val_loss: 1.3563e-04
# Epoch 62/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1838e-04 - val_loss: 1.2209e-04
# Epoch 63/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.2183e-04 - val_loss: 1.3107e-04
# Epoch 64/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1811e-04 - val_loss: 1.2809e-04
# Epoch 65/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 2.1663e-04 - val_loss: 1.2077e-04
# Epoch 66/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1726e-04 - val_loss: 1.1333e-04
# Epoch 67/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1745e-04 - val_loss: 1.1535e-04
# Epoch 68/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1703e-04 - val_loss: 1.1540e-04
# Epoch 69/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1766e-04 - val_loss: 1.1201e-04
# Epoch 70/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2250e-04 - val_loss: 1.1333e-04
# Epoch 71/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1642e-04 - val_loss: 1.3097e-04
# Epoch 72/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1847e-04 - val_loss: 1.4701e-04
# Epoch 73/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2457e-04 - val_loss: 1.3629e-04
# Epoch 74/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1831e-04 - val_loss: 1.3039e-04
# Epoch 75/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1519e-04 - val_loss: 1.1408e-04
# Epoch 76/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1560e-04 - val_loss: 1.1148e-04
# Epoch 77/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1772e-04 - val_loss: 1.1860e-04
# Epoch 78/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1451e-04 - val_loss: 1.1408e-04
# Epoch 79/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1423e-04 - val_loss: 1.2945e-04
# Epoch 80/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1631e-04 - val_loss: 1.2155e-04
# Epoch 81/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1404e-04 - val_loss: 1.1822e-04
# Epoch 82/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1405e-04 - val_loss: 1.2964e-04
# Epoch 83/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1659e-04 - val_loss: 1.3604e-04
# Epoch 84/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1596e-04 - val_loss: 1.1186e-04
# Epoch 85/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1352e-04 - val_loss: 1.1268e-04
# Epoch 86/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1890e-04 - val_loss: 1.1215e-04
# Epoch 87/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1581e-04 - val_loss: 1.1127e-04
# Epoch 88/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1285e-04 - val_loss: 1.1055e-04
# Epoch 89/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1191e-04 - val_loss: 1.1063e-04
# Epoch 90/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.1216e-04 - val_loss: 1.1083e-04
# Epoch 91/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1412e-04 - val_loss: 1.2540e-04
# Epoch 92/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1208e-04 - val_loss: 1.1469e-04
# Epoch 93/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1187e-04 - val_loss: 1.1446e-04
# Epoch 94/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1363e-04 - val_loss: 1.3493e-04
# Epoch 95/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1517e-04 - val_loss: 1.1597e-04
# Epoch 96/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.0931e-04 - val_loss: 1.2167e-04
# Epoch 97/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1065e-04 - val_loss: 1.1011e-04
# Epoch 98/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1268e-04 - val_loss: 1.5082e-04
# Epoch 99/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1495e-04 - val_loss: 1.4996e-04
# Epoch 100/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1576e-04 - val_loss: 1.1515e-04
# Epoch 101/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1051e-04 - val_loss: 1.1116e-04
# Epoch 102/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1053e-04 - val_loss: 1.1779e-04
# Epoch 103/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0743e-04 - val_loss: 1.1956e-04
# Epoch 104/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0819e-04 - val_loss: 1.1288e-04
# Epoch 105/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 2.0781e-04 - val_loss: 1.1140e-04
# Epoch 106/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0686e-04 - val_loss: 1.1088e-04
# Epoch 107/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1049e-04 - val_loss: 1.5181e-04
# Epoch 108/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1612e-04 - val_loss: 1.0851e-04
# Epoch 109/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1741e-04 - val_loss: 1.1225e-04
# Epoch 110/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1210e-04 - val_loss: 1.2943e-04
# Epoch 111/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.1391e-04 - val_loss: 1.1626e-04
# Epoch 112/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0850e-04 - val_loss: 1.1745e-04
# Epoch 113/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0986e-04 - val_loss: 1.1119e-04
# Epoch 114/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0840e-04 - val_loss: 1.1916e-04
# Epoch 115/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0497e-04 - val_loss: 1.1416e-04
# Epoch 116/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0642e-04 - val_loss: 1.0767e-04
# Epoch 117/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0646e-04 - val_loss: 1.0848e-04
# Epoch 118/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0811e-04 - val_loss: 1.0703e-04
# Epoch 119/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.0456e-04 - val_loss: 1.0726e-04
# Epoch 120/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.1076e-04 - val_loss: 1.1320e-04
# Epoch 121/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0446e-04 - val_loss: 1.1220e-04
# Epoch 122/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0337e-04 - val_loss: 1.0844e-04
# Epoch 123/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0802e-04 - val_loss: 1.1185e-04
# Epoch 124/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0528e-04 - val_loss: 1.3775e-04
# Epoch 125/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.0864e-04 - val_loss: 1.0607e-04
# Epoch 126/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 2.0459e-04 - val_loss: 1.1338e-04
# Epoch 127/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0647e-04 - val_loss: 1.3938e-04
# Epoch 128/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0474e-04 - val_loss: 1.0893e-04
# Epoch 129/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.0653e-04 - val_loss: 1.0613e-04
# Epoch 130/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0394e-04 - val_loss: 1.1278e-04
# Epoch 131/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0122e-04 - val_loss: 1.0619e-04
# Epoch 132/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0572e-04 - val_loss: 1.4349e-04
# Epoch 133/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1238e-04 - val_loss: 1.0969e-04
# Epoch 134/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0529e-04 - val_loss: 1.1074e-04
# Epoch 135/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0064e-04 - val_loss: 1.1321e-04
# Epoch 136/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0063e-04 - val_loss: 1.0733e-04
# Epoch 137/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0152e-04 - val_loss: 1.1684e-04
# Epoch 138/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0201e-04 - val_loss: 1.0410e-04
# Epoch 139/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.0359e-04 - val_loss: 1.1713e-04
# Epoch 140/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0856e-04 - val_loss: 1.0770e-04
# Epoch 141/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0062e-04 - val_loss: 1.0355e-04
# Epoch 142/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0828e-04 - val_loss: 1.5069e-04
# Epoch 143/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0184e-04 - val_loss: 1.0588e-04
# Epoch 144/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0075e-04 - val_loss: 1.0820e-04
# Epoch 145/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9604e-04 - val_loss: 1.0734e-04
# Epoch 146/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9734e-04 - val_loss: 1.0236e-04
# Epoch 147/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0116e-04 - val_loss: 1.5819e-04
# Epoch 148/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.0881e-04 - val_loss: 1.1521e-04
# Epoch 149/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0984e-04 - val_loss: 1.9199e-04
# Epoch 150/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.2169e-04 - val_loss: 1.0130e-04
# Epoch 151/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.0633e-04 - val_loss: 1.1403e-04
# Epoch 152/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9442e-04 - val_loss: 1.0236e-04
# Epoch 153/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.9919e-04 - val_loss: 1.1903e-04
# Epoch 154/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9374e-04 - val_loss: 9.9934e-05
# Epoch 155/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.9382e-04 - val_loss: 1.0216e-04
# Epoch 156/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.9560e-04 - val_loss: 1.2722e-04
# Epoch 157/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9167e-04 - val_loss: 1.0074e-04
# Epoch 158/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9010e-04 - val_loss: 9.9505e-05
# Epoch 159/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.9532e-04 - val_loss: 1.0920e-04
# Epoch 160/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.8946e-04 - val_loss: 9.9578e-05
# Epoch 161/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9120e-04 - val_loss: 1.0599e-04
# Epoch 162/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.9023e-04 - val_loss: 1.0277e-04
# Epoch 163/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 2.0130e-04 - val_loss: 9.7929e-05
# Epoch 164/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 2.2048e-04 - val_loss: 3.0756e-04
# Epoch 165/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 2.3418e-04 - val_loss: 1.2410e-04
# Epoch 166/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.9803e-04 - val_loss: 1.0696e-04
# Epoch 167/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8848e-04 - val_loss: 1.0805e-04
# Epoch 168/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8700e-04 - val_loss: 9.8038e-05
# Epoch 169/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.8613e-04 - val_loss: 1.0132e-04
# Epoch 170/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8805e-04 - val_loss: 1.0776e-04
# Epoch 171/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.8498e-04 - val_loss: 1.0372e-04
# Epoch 172/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.8471e-04 - val_loss: 9.7504e-05
# Epoch 173/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8997e-04 - val_loss: 9.5428e-05
# Epoch 174/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0643e-04 - val_loss: 1.8839e-04
# Epoch 175/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 2.0114e-04 - val_loss: 1.0261e-04
# Epoch 176/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8731e-04 - val_loss: 9.6934e-05
# Epoch 177/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.7978e-04 - val_loss: 9.5899e-05
# Epoch 178/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8138e-04 - val_loss: 9.6772e-05
# Epoch 179/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.8851e-04 - val_loss: 1.5219e-04
# Epoch 180/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.8431e-04 - val_loss: 9.3609e-05
# Epoch 181/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.7952e-04 - val_loss: 1.0160e-04
# Epoch 182/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8246e-04 - val_loss: 1.2132e-04
# Epoch 183/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 1.8496e-04 - val_loss: 9.3173e-05
# Epoch 184/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.7630e-04 - val_loss: 1.0182e-04
# Epoch 185/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.7576e-04 - val_loss: 1.1300e-04
# Epoch 186/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.8222e-04 - val_loss: 1.3067e-04
# Epoch 187/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.7796e-04 - val_loss: 9.7632e-05
# Epoch 188/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.7890e-04 - val_loss: 9.7034e-05
# Epoch 189/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.8622e-04 - val_loss: 2.2208e-04
# Epoch 190/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9682e-04 - val_loss: 9.0415e-05
# Epoch 191/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.6983e-04 - val_loss: 8.9653e-05
# Epoch 192/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.7218e-04 - val_loss: 9.1818e-05
# Epoch 193/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.7438e-04 - val_loss: 9.2404e-05
# Epoch 194/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.8706e-04 - val_loss: 1.1383e-04
# Epoch 195/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9121e-04 - val_loss: 9.6455e-05
# Epoch 196/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.8162e-04 - val_loss: 1.0524e-04
# Epoch 197/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.6948e-04 - val_loss: 8.9805e-05
# Epoch 198/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.7013e-04 - val_loss: 9.4686e-05
# Epoch 199/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.7773e-04 - val_loss: 8.9262e-05
# Epoch 200/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.7392e-04 - val_loss: 1.0681e-04
# Epoch 201/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.6666e-04 - val_loss: 9.0804e-05
# Epoch 202/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.6713e-04 - val_loss: 8.7073e-05
# Epoch 203/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.6418e-04 - val_loss: 8.4890e-05
# Epoch 204/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.6169e-04 - val_loss: 8.3459e-05
# Epoch 205/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.6670e-04 - val_loss: 9.4697e-05
# Epoch 206/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 1.6216e-04 - val_loss: 8.5999e-05
# Epoch 207/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.6210e-04 - val_loss: 9.4156e-05
# Epoch 208/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.6197e-04 - val_loss: 1.2157e-04
# Epoch 209/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.6251e-04 - val_loss: 8.6209e-05
# Epoch 210/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.7209e-04 - val_loss: 1.1477e-04
# Epoch 211/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.7910e-04 - val_loss: 1.3997e-04
# Epoch 212/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.8386e-04 - val_loss: 8.1769e-05
# Epoch 213/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.5968e-04 - val_loss: 8.3979e-05
# Epoch 214/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.6022e-04 - val_loss: 9.9833e-05
# Epoch 215/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.6026e-04 - val_loss: 8.5925e-05
# Epoch 216/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.5724e-04 - val_loss: 1.0489e-04
# Epoch 217/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.6836e-04 - val_loss: 9.0541e-05
# Epoch 218/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 1.5861e-04 - val_loss: 8.9111e-05
# Epoch 219/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.5498e-04 - val_loss: 1.1445e-04
# Epoch 220/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1
1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2196e-04 - val_loss: 8.1585e-05
# Epoch 372/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.3023e-04 - val_loss: 6.3948e-05
# Epoch 373/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1745e-04 - val_loss: 6.3650e-05
# Epoch 374/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2306e-04 - val_loss: 6.6240e-05
# Epoch 375/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.1817e-04 - val_loss: 6.6770e-05
# Epoch 376/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1787e-04 - val_loss: 6.6641e-05
# Epoch 377/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.2072e-04 - val_loss: 6.3788e-05
# Epoch 378/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1970e-04 - val_loss: 1.1591e-04
# Epoch 379/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.3785e-04 - val_loss: 8.0886e-05
# Epoch 380/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2378e-04 - val_loss: 6.7836e-05
# Epoch 381/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.2505e-04 - val_loss: 7.2291e-05
# Epoch 382/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.5543e-04 - val_loss: 7.2343e-05
# Epoch 383/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.5446e-04 - val_loss: 9.5614e-05
# Epoch 384/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.6619e-04 - val_loss: 6.1676e-05
# Epoch 385/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.3238e-04 - val_loss: 7.1515e-05
# Epoch 386/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2450e-04 - val_loss: 6.6825e-05
# Epoch 387/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2299e-04 - val_loss: 6.7955e-05
# Epoch 388/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.1588e-04 - val_loss: 7.3217e-05
# Epoch 389/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2634e-04 - val_loss: 6.2350e-05
# Epoch 390/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1615e-04 - val_loss: 7.8182e-05
# Epoch 391/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1929e-04 - val_loss: 6.1221e-05
# Epoch 392/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1554e-04 - val_loss: 7.6845e-05
# Epoch 393/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2053e-04 - val_loss: 6.2418e-05
# Epoch 394/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1514e-04 - val_loss: 6.0839e-05
# Epoch 395/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1528e-04 - val_loss: 6.2476e-05
# Epoch 396/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1634e-04 - val_loss: 6.3543e-05
# Epoch 397/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.1384e-04 - val_loss: 7.9750e-05
# Epoch 398/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2795e-04 - val_loss: 1.1194e-04
# Epoch 399/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.4508e-04 - val_loss: 7.1498e-05
# Epoch 400/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.3821e-04 - val_loss: 6.1567e-05
# Epoch 401/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1711e-04 - val_loss: 6.1068e-05
# Epoch 402/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1677e-04 - val_loss: 9.9524e-05
# Epoch 403/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.3158e-04 - val_loss: 7.1318e-05
# Epoch 404/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1611e-04 - val_loss: 6.1151e-05
# Epoch 405/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1602e-04 - val_loss: 6.4117e-05
# Epoch 406/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.2559e-04 - val_loss: 6.2736e-05
# Epoch 407/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1515e-04 - val_loss: 6.2862e-05
# Epoch 408/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1615e-04 - val_loss: 6.0247e-05
# Epoch 409/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.1440e-04 - val_loss: 6.2973e-05
# Epoch 410/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1689e-04 - val_loss: 6.2140e-05
# Epoch 411/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.2373e-04 - val_loss: 7.2181e-05
# Epoch 412/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1352e-04 - val_loss: 6.2718e-05
# Epoch 413/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1426e-04 - val_loss: 6.8175e-05
# Epoch 414/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.3190e-04 - val_loss: 6.7359e-05
# Epoch 415/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2363e-04 - val_loss: 7.0144e-05
# Epoch 416/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1620e-04 - val_loss: 6.1190e-05
# Epoch 417/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1665e-04 - val_loss: 6.1722e-05
# Epoch 418/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1616e-04 - val_loss: 6.9688e-05
# Epoch 419/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.1178e-04 - val_loss: 6.1524e-05
# Epoch 420/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1571e-04 - val_loss: 5.9812e-05
# Epoch 421/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2167e-04 - val_loss: 6.5317e-05
# Epoch 422/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.2263e-04 - val_loss: 9.8963e-05
# Epoch 423/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2684e-04 - val_loss: 7.2382e-05
# Epoch 424/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.3791e-04 - val_loss: 1.0891e-04
# Epoch 425/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.3349e-04 - val_loss: 5.9803e-05
# Epoch 426/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.2110e-04 - val_loss: 1.0819e-04
# Epoch 427/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2278e-04 - val_loss: 7.4533e-05
# Epoch 428/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.2532e-04 - val_loss: 6.2293e-05
# Epoch 429/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1252e-04 - val_loss: 6.2257e-05
# Epoch 430/1000
# 9/9 [==============================] - 0s 19ms/step - loss: 1.1230e-04 - val_loss: 6.0050e-05
# Epoch 431/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1867e-04 - val_loss: 9.7702e-05
# Epoch 432/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1864e-04 - val_loss: 5.9111e-05
# Epoch 433/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1129e-04 - val_loss: 5.9750e-05
# Epoch 434/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1598e-04 - val_loss: 5.8572e-05
# Epoch 435/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1686e-04 - val_loss: 5.8457e-05
# Epoch 436/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1565e-04 - val_loss: 6.8620e-05
# Epoch 437/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.2300e-04 - val_loss: 1.1909e-04
# Epoch 438/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.5455e-04 - val_loss: 5.8541e-05
# Epoch 439/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2521e-04 - val_loss: 5.8339e-05
# Epoch 440/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.1448e-04 - val_loss: 5.8343e-05
# Epoch 441/1000
# 9/9 [==============================] - 0s 25ms/step - loss: 1.1319e-04 - val_loss: 5.8483e-05
# Epoch 442/1000
# ...
# Epoch 590/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1804e-04 - val_loss: 6.1402e-05
# Epoch 591/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1583e-04 - val_loss: 5.3958e-05
# Epoch 592/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0961e-04 - val_loss: 5.3828e-05
# Epoch 593/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0884e-04 - val_loss: 5.4692e-05
# Epoch 594/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0980e-04 - val_loss: 5.4221e-05
# Epoch 595/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0753e-04 - val_loss: 7.1011e-05
# Epoch 596/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1262e-04 - val_loss: 5.4742e-05
# Epoch 597/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0958e-04 - val_loss: 5.4677e-05
# Epoch 598/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1502e-04 - val_loss: 6.7324e-05
# Epoch 599/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1294e-04 - val_loss: 5.3841e-05
# Epoch 600/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0668e-04 - val_loss: 5.3975e-05
# Epoch 601/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0731e-04 - val_loss: 5.6488e-05
# Epoch 602/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0861e-04 - val_loss: 7.3219e-05
# Epoch 603/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1931e-04 - val_loss: 5.5545e-05
# Epoch 604/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0974e-04 - val_loss: 6.1338e-05
# Epoch 605/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.3685e-04 - val_loss: 1.3758e-04
# Epoch 606/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.3603e-04 - val_loss: 7.2345e-05
# Epoch 607/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1780e-04 - val_loss: 7.5888e-05
# Epoch 608/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2253e-04 - val_loss: 7.3146e-05
# Epoch 609/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2403e-04 - val_loss: 5.4419e-05
# Epoch 610/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2562e-04 - val_loss: 6.8655e-05
# Epoch 611/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0881e-04 - val_loss: 5.9095e-05
# Epoch 612/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0813e-04 - val_loss: 7.9609e-05
# Epoch 613/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2289e-04 - val_loss: 6.4471e-05
# Epoch 614/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.1147e-04 - val_loss: 5.3746e-05
# Epoch 615/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0649e-04 - val_loss: 5.4288e-05
# Epoch 616/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0384e-04 - val_loss: 5.8504e-05
# Epoch 617/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0284e-04 - val_loss: 5.6960e-05
# Epoch 618/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.1250e-04 - val_loss: 6.0162e-05
# Epoch 619/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.3019e-04 - val_loss: 5.7768e-05
# Epoch 620/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.2674e-04 - val_loss: 7.7005e-05
# Epoch 621/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1431e-04 - val_loss: 5.3420e-05
# Epoch 622/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0921e-04 - val_loss: 5.4610e-05
# Epoch 623/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2433e-04 - val_loss: 5.5164e-05
# Epoch 624/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.2165e-04 - val_loss: 9.3935e-05
# Epoch 625/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1114e-04 - val_loss: 7.2153e-05
# Epoch 626/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1966e-04 - val_loss: 7.8769e-05
# Epoch 627/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1517e-04 - val_loss: 5.6136e-05
# Epoch 628/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0870e-04 - val_loss: 5.6144e-05
# Epoch 629/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0543e-04 - val_loss: 5.3697e-05
# Epoch 630/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0373e-04 - val_loss: 6.7711e-05
# Epoch 631/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0210e-04 - val_loss: 5.3375e-05
# Epoch 632/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1038e-04 - val_loss: 5.3703e-05
# Epoch 633/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0197e-04 - val_loss: 5.8984e-05
# Epoch 634/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0793e-04 - val_loss: 6.6157e-05
# Epoch 635/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0327e-04 - val_loss: 5.3202e-05
# Epoch 636/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0765e-04 - val_loss: 7.1372e-05
# Epoch 637/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0804e-04 - val_loss: 5.3287e-05
# Epoch 638/1000
# 9/9 [==============================] - 0s 25ms/step - loss: 1.0852e-04 - val_loss: 5.3569e-05
# Epoch 639/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0760e-04 - val_loss: 6.7633e-05
# Epoch 640/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0439e-04 - val_loss: 5.6822e-05
# Epoch 641/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0512e-04 - val_loss: 5.5090e-05
# Epoch 642/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0416e-04 - val_loss: 5.6644e-05
# Epoch 643/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0688e-04 - val_loss: 6.1755e-05
# Epoch 644/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.1276e-04 - val_loss: 7.8124e-05
# Epoch 645/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.3380e-04 - val_loss: 1.1800e-04
# Epoch 646/1000
# 9/9 [==============================] - 0s 26ms/step - loss: 1.2817e-04 - val_loss: 6.9300e-05
# Epoch 647/1000
# 9/9 [==============================] - 0s 26ms/step - loss: 1.1204e-04 - val_loss: 5.4805e-05
# Epoch 648/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0424e-04 - val_loss: 5.8855e-05
# Epoch 649/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0967e-04 - val_loss: 5.4185e-05
# Epoch 650/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0761e-04 - val_loss: 5.6269e-05
# Epoch 651/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2263e-04 - val_loss: 8.6259e-05
# Epoch 652/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1924e-04 - val_loss: 8.0681e-05
# Epoch 653/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1326e-04 - val_loss: 7.2471e-05
# Epoch 654/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0827e-04 - val_loss: 6.2752e-05
# Epoch 655/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0439e-04 - val_loss: 5.3128e-05
# Epoch 656/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0149e-04 - val_loss: 5.3249e-05
# Epoch 657/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0697e-04 - val_loss: 5.2948e-05
# Epoch 658/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0674e-04 - val_loss: 6.7533e-05
# Epoch 659/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0415e-04 - val_loss: 5.4462e-05
# Epoch 660/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0989e-04 - val_loss: 6.5509e-05
# Epoch 661/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0596e-04 - val_loss: 5.9620e-05
# Epoch 662/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0323e-04 - val_loss: 8.8374e-05
# Epoch 663/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0909e-04 - val_loss: 6.1493e-05
# Epoch 664/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0375e-04 - val_loss: 8.5909e-05
# Epoch 665/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1179e-04 - val_loss: 6.1089e-05
# Epoch 666/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0197e-04 - val_loss: 5.3261e-05
# Epoch 667/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0311e-04 - val_loss: 7.5946e-05
# Epoch 668/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0333e-04 - val_loss: 5.3297e-05
# Epoch 669/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0352e-04 - val_loss: 5.7581e-05
# Epoch 670/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0494e-04 - val_loss: 5.3650e-05
# Epoch 671/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0331e-04 - val_loss: 5.9409e-05
# Epoch 672/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1240e-04 - val_loss: 5.3267e-05
# Epoch 673/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0299e-04 - val_loss: 5.5585e-05
# Epoch 674/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2218e-04 - val_loss: 5.4617e-05
# Epoch 675/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0815e-04 - val_loss: 5.8411e-05
# Epoch 676/1000
# 9/9 [==============================] - 0s 25ms/step - loss: 1.0688e-04 - val_loss: 5.5832e-05
# Epoch 677/1000
# 9/9 [==============================] - 0s 25ms/step - loss: 1.0913e-04 - val_loss: 6.0936e-05
# Epoch 678/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0837e-04 - val_loss: 5.2888e-05
# Epoch 679/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0279e-04 - val_loss: 6.2736e-05
# Epoch 680/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0368e-04 - val_loss: 5.3291e-05
# Epoch 681/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1071e-04 - val_loss: 6.2961e-05
# Epoch 682/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0597e-04 - val_loss: 5.3638e-05
# Epoch 683/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1090e-04 - val_loss: 5.3098e-05
# Epoch 684/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0291e-04 - val_loss: 5.5553e-05
# Epoch 685/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.1087e-04 - val_loss: 8.7984e-05
# Epoch 686/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.1511e-04 - val_loss: 6.5029e-05
# Epoch 687/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2093e-04 - val_loss: 6.4478e-05
# Epoch 688/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1241e-04 - val_loss: 8.6642e-05
# Epoch 689/1000
# 9/9 [==============================] - 0s 25ms/step - loss: 1.0488e-04 - val_loss: 5.5472e-05
# Epoch 690/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0341e-04 - val_loss: 5.2574e-05
# Epoch 691/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0233e-04 - val_loss: 5.2568e-05
# Epoch 692/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0247e-04 - val_loss: 5.3238e-05
# Epoch 693/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0175e-04 - val_loss: 5.3198e-05
# Epoch 694/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0015e-04 - val_loss: 5.8243e-05
# Epoch 695/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1121e-04 - val_loss: 6.0713e-05
# Epoch 696/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0971e-04 - val_loss: 5.6294e-05
# Epoch 697/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0315e-04 - val_loss: 6.2403e-05
# Epoch 698/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0615e-04 - val_loss: 8.0513e-05
# Epoch 699/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1410e-04 - val_loss: 5.6820e-05
# Epoch 700/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.2015e-04 - val_loss: 9.4034e-05
# Epoch 701/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.5708e-04 - val_loss: 2.1306e-04
# Epoch 702/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.7332e-04 - val_loss: 2.2808e-04
# Epoch 703/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.6238e-04 - val_loss: 9.7751e-05
# Epoch 704/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1898e-04 - val_loss: 7.8272e-05
# Epoch 705/1000
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0773e-04 - val_loss: 5.2353e-05
# Epoch 706/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0320e-04 - val_loss: 5.2428e-05
# Epoch 707/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.1198e-04 - val_loss: 7.2420e-05
# Epoch 708/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2675e-04 - val_loss: 6.1855e-05
# Epoch 709/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.2265e-04 - val_loss: 5.2465e-05
# Epoch 710/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1887e-04 - val_loss: 5.6018e-05
# Epoch 711/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1300e-04 - val_loss: 6.0903e-05
# Epoch 712/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1075e-04 - val_loss: 7.3653e-05
# Epoch 713/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0856e-04 - val_loss: 5.8276e-05
# Epoch 714/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0139e-04 - val_loss: 7.8880e-05
# Epoch 715/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0968e-04 - val_loss: 5.3191e-05
# Epoch 716/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0134e-04 - val_loss: 5.5036e-05
# Epoch 717/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0336e-04 - val_loss: 5.4375e-05
# Epoch 718/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0287e-04 - val_loss: 6.0376e-05
# Epoch 719/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0679e-04 - val_loss: 5.5385e-05
# Epoch 720/1000
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0330e-04 - val_loss: 6.3634e-05
# Epoch 721/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1146e-04 - val_loss: 7.2760e-05
# Epoch 722/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0844e-04 - val_loss: 5.2391e-05
# Epoch 723/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0148e-04 - val_loss: 7.1111e-05
# Epoch 724/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0836e-04 - val_loss: 1.0165e-04
# Epoch 725/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0947e-04 - val_loss: 5.7358e-05
# Epoch 726/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0826e-04 - val_loss: 5.6332e-05
# Epoch 727/1000
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0381e-04 - val_loss: 6.1665e-05
# Epoch 728/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0364e-04 - val_loss: 5.6270e-05
# Epoch 729/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.0361e-04 - val_loss: 6.7552e-05
# Epoch 730/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1499e-04 - val_loss: 5.9223e-05
# Epoch 731/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.1636e-04 - val_loss: 5.3620e-05
# Epoch 732/1000
# 9/9 [==============================] - 0s 23ms/step - loss: 1.2362e-04 - val_loss: 6.5012e-05
# Epoch 733/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.2307e-04 - val_loss: 5.4654e-05
# Epoch 734/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.0755e-04 - val_loss: 7.0765e-05
# Epoch 735/1000
# 9/9 [==============================] - 0s 22ms/step - loss: 1.1005e-04 - val_loss: 5.2358e-05
# Epoch 00735: early stopping

# %%
#Loss Visualization for data training and validation

plt.figure(figsize=(15,10))
plt.plot(model_train.history['loss'])
plt.plot(model_train.history['val_loss'])
plt.title('Model Performance')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Validation'], loc='upper right')
plt.show()

# %%
result = model.predict(train_X)

# %%
train_y.shape
# Out:
# (3336, 1)

# %%
result.shape
# Out:
# (3336, 1)

# %%
#Invert Scalled Value into Actual Value

result = scalerMinMax.inverse_transform(result.reshape(-1,1))
train_y = scalerMinMax.inverse_transform(train_y.reshape(-1,1))

# %%
#Flatten the Data

result = result.flatten()
train_y = train_y.flatten()

# %%
#Check the RMSE and MAE (Training Process)

rmse_train = np.sqrt(mean_squared_error(train_y, result))
print('Train Root Mean Squared Error:', rmse_train)

mae_train = (mean_absolute_error(train_y, result))
print('Train Mean Absolute Error:', mae_train)
# Out:
# Train Root Mean Squared Error: 8.168024350394687
# Train Mean Absolute Error: 5.532743089626703

# %%
#Make the length date -4
data_train = data_train[4:]
data_test = data_test[4:]

# %%
#Visuzalize the Predicted Result and Actual Data Train

plt.figure(figsize=(20,10))
plt.title("Training Predicted Price")
plt.xlabel('Date')
plt.ylabel('Price')
plt.plot(data_train['Date'],result)
plt.plot(data_train['Date'],train_y)
plt.legend(['True','Predict'], loc='upper right')
plt.show()

# %% [markdown]
# ## Testing

# %%
#Testing
predicted_result = model.predict(test_X, verbose=0)

# %%
#Invert Scalled Value into Actual Value
predicted_result = scalerMinMax.inverse_transform(predicted_result.reshape(-1,1))
test_y = scalerMinMax.inverse_transform(test_y.reshape(-1,1))

# %%
#Flatten the Data

predicted_result = predicted_result.flatten()
test_y = test_y.flatten()

# %%
#Check the RMSE and MAE (Testing Process)

rmse = np.sqrt(mean_squared_error(test_y, predicted_result))
print('Test Root Mean Squared Error:', rmse)

mae = (mean_absolute_error(test_y, predicted_result))
print('Test Mean Absolute Error:', mae)
# Out:
# Test Root Mean Squared Error: 15.219309753086899
# Test Mean Absolute Error: 10.151560942905766

# %%
#Visuzalize the Predicted Result and Actual Data Test

plt.figure(figsize=(20,10))
plt.title("Predicted Price")
plt.xlabel('Date')
plt.ylabel('Price')
plt.plot(data_test['Date'], predicted_result)
plt.plot(data_test['Date'], test_y)
plt.legend(['True','Predict'], loc='upper right')
plt.show()
