# %% [markdown]
# # **Gold Price Prediction Using CNN-LSTM**

# %% [markdown]
# ## Import and Install Library

# %%
# !pip install -q keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from google.colab import drive

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, TimeDistributed, Conv1D
from tensorflow.python.keras.layers.pooling import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Flatten

import random as python_random

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

import datetime

# %% [markdown]
# ## Load Dataset

# %%
#Mount to google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/TugasAkhir/Code/"

# %%
data = pd.read_excel("/content/drive/MyDrive/TugasAkhir/Code/Dataset/2-weekly.xlsx")

# %%
data.head()
# Out:
#         Date  Prices
# 0 1978-12-29  226.00
# 1 1979-01-05  225.50
# 2 1979-01-12  217.60
# 3 1979-01-19  230.55
# 4 1979-01-26  235.45

# %%
data.tail()
# Out:
#            Date   Prices
# 2200 2021-02-26  1742.85
# 2201 2021-03-05  1696.25
# 2202 2021-03-12  1704.80
# 2203 2021-03-19  1735.20
# 2204 2021-03-26  1731.80

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2205 non-null   datetime64[ns]
#  1   Prices  2205 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 34.6 KB

# %% [markdown]
# ## Pre-Processing

# %%
#Check the pattern of dataset

plt.figure(figsize=(20,10))
plt.plot(data['Date'], data['Prices'])
plt.title("Data Prices Gold Daily 1980 - 2020 ", fontsize=16)
plt.ylabel("Prices", fontsize=14)
plt.xlabel("Years", fontsize=14)
plt.show()

# %%
#Filter Data
data = data[(data['Date'] >= pd.Timestamp(2005,3,26)) & (data['Date'] <= pd.Timestamp(2021,3,26))]

# %%
#Check the pattern of dataset after filter

plt.figure(figsize=(20,10))
plt.plot(data['Date'], data['Prices'])
plt.title("Data Prices Gold Daily 2005 - 2020 ", fontsize=16)
plt.ylabel("Prices", fontsize=14)
plt.xlabel("Years", fontsize=14)
plt.show()

# %%
#Check the types of all atributes
data.dtypes
# Out:
# Date      datetime64[ns]
# Prices           float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 835 entries, 1370 to 2204
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    835 non-null    datetime64[ns]
#  1   Prices  835 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 19.6 KB

# %% [markdown]
# ### Check

# %%
#Split into Data Train and Data Test (80:20 and 60:40)
train_size = int(len(data) * 0.60)
test_size = (int(len(data) - train_size))

#Data training
data_train = data[0:train_size]

#Data testing
data_test = data[train_size:len(data)]

print("The amount of data train: ", len(data_train))
print("The amount of data train: ", len(data_test))
# Out:
# The amount of data train:  501
# The amount of data train:  334

# %%
#Check missing values in data train
data_train.isnull().sum()
# Out:
# Date      0
# Prices    0
# dtype: int64

# %%
#Check missing values in data test
data_test.isnull().sum()
# Out:
# Date      0
# Prices    0
# dtype: int64

# %%
#Make data train into numpy array
arr_price_train = data_train['Prices'].to_numpy()
# arr_date_train = data_train['Date'].to_numpy()

#Make data test into numpy array
arr_price_test = data_test['Prices'].to_numpy()
# arr_date_test = data_test['Date'].to_numpy()

# %%
scalerMinMax = MinMaxScaler()
# scalerStandard = StandardScaler() 

#Normalize the data train
scaled_data_train = scalerMinMax.fit_transform(arr_price_train.reshape(-1,1))

#Normalize the data test
scaled_data_test = scalerMinMax.fit_transform(arr_price_test.reshape(-1,1))

# %%
#Checking the normalize result
for i in range(len(scaled_data_train)):
    if (i <= 5):
        print(scaled_data_train[i])
# Out:
# [0.00627895]
# [0.00494081]
# [0.00452908]
# [0.01139132]
# [0.01214617]
# [0.0049065]

# %% [markdown]
# The first step is to split the input sequences into subsequences that can be processed by the CNN model. For example, we can first split our univariate time series data into input/output samples with four steps as input and one as output. Each sample can then be split into two sub-samples, each with two time steps. The CNN can interpret each subsequence of two time steps and provide a time series of interpretations of the subsequences to the LSTM model to process as input.
#
# We can parameterize this and define the number of subsequences as n_seq and the number of time steps per subsequence as n_steps. The input data can then be reshaped to have the required structure

# %%
#Split a univariate sequence into samples
def splitSequences(data, n_steps):
    x, y = list(),list()
    for i in range(len(data)):
        #Find the end of this pattern
        end = i + n_steps
        #Check if we are beyond the sequence
        if end > len(data)-1:
            break
        #Gather input and outputs part of the pattern
        seq_x, seq_y = data[i:end], data[end]
        x.append(seq_x)
        y.append(seq_y)
    return x, y

# %%
#Scaled data train became the input sequence
input_seq_train = scaled_data_train

#Scaled data test became the input sequence
input_seq_test = scaled_data_test

# %%
#Choose a number of time steps (In this case time steps = 1)

n_steps = 4
train_X, train_y = splitSequences(input_seq_train, n_steps)
test_X, test_y = splitSequences(input_seq_test, n_steps)

print("The amount of data train: ", len(train_X))
print("The amount of data train: ", len(test_X))
# Out:
# The amount of data train:  497
# The amount of data train:  330

# %%
#Make data into numpy array

train_X = np.asarray(train_X)
train_y = np.asarray(train_y)

test_X = np.asarray(test_X)
test_y = np.asarray(test_y)

# %%
#Reshape from [samples, timesteps] into[samples, subsequence, timesteps, features]
n_features = 1
n_steps = 4

# #Reshape for data train
train_X = train_X.reshape((train_X.shape[0], train_X.shape[1], n_features))

#Reshape for data test
test_X = test_X.reshape((test_X.shape[0],test_X.shape[1], n_features))

# %% [markdown]
# ## Building Model

# %% [markdown]
# ![cnn-lstm fix.png](data:image/png;base64,...)

# %%
#Not get random result

np.random.seed(123)
python_random.seed(123)
tf.random.set_seed(1234)

# %%
# Define Model CNN-LSTM

model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_steps, n_features), return_sequences=True))
model.add(LSTM(100, activation='relu'))
# model.add(Dropout(0.1))
model.add(Dense(1, activation="relu")) # Output Layer
model.compile(optimizer='Adam', loss='mean_squared_error')

earlyStop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 100)            40800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training Model

# %%
#Training Model
model_train = model.fit(train_X, train_y, validation_split=0.33, epochs=1000, batch_size=128, verbose=1, callbacks=[earlyStop])
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 3s 274ms/step - loss: 0.1513 - val_loss: 0.4931
# Epoch 2/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1351 - val_loss: 0.4405
# Epoch 3/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1186 - val_loss: 0.3841
# Epoch 4/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1018 - val_loss: 0.3194
# Epoch 5/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0787 - val_loss: 0.2445
# Epoch 6/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0541 - val_loss: 0.1625
# Epoch 7/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0329 - val_loss: 0.0812
# Epoch 8/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0204 - val_loss: 0.0214
# Epoch 9/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0181 - val_loss: 0.0031
# Epoch 10/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0229 - val_loss: 0.0025
# Epoch 11/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0196 - val_loss: 0.0083
# Epoch 12/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0124 - val_loss: 0.0225
# Epoch 13/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0112 - val_loss: 0.0306
# Epoch 14/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0101 - val_loss: 0.0235
# Epoch 15/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0086 - val_loss: 0.0082
# Epoch 16/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 17/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0034 - val_loss: 0.0046
# Epoch 18/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0024 - val_loss: 0.0054
# Epoch 19/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 20/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0012 - val_loss: 0.0072
# Epoch 21/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0013 - val_loss: 0.0166
# Epoch 22/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0014 - val_loss: 0.0193
# Epoch 23/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0013 - val_loss: 0.0112
# Epoch 24/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0012 - val_loss: 0.0078
# Epoch 25/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0011 - val_loss: 0.0086
# Epoch 26/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 9.5249e-04 - val_loss: 0.0092
# Epoch 27/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 8.9307e-04 - val_loss: 0.0075
# Epoch 28/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 8.6658e-04 - val_loss: 0.0052
# Epoch 29/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 8.6235e-04 - val_loss: 0.0045
# Epoch 30/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 7.7358e-04 - val_loss: 0.0054
# Epoch 31/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 7.4667e-04 - val_loss: 0.0061
# Epoch 32/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 7.6459e-04 - val_loss: 0.0051
# Epoch 33/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 7.5149e-04 - val_loss: 0.0046
# Epoch 34/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 6.8983e-04 - val_loss: 0.0053
# Epoch 35/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 6.9566e-04 - val_loss: 0.0055
# Epoch 36/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 6.7948e-04 - val_loss: 0.0046
# Epoch 37/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 6.6625e-04 - val_loss: 0.0040
# Epoch 38/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 7.3763e-04 - val_loss: 0.0045
# Epoch 39/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 6.4080e-04 - val_loss: 0.0047
# Epoch 40/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 6.4480e-04 - val_loss: 0.0042
# Epoch 41/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 6.9337e-04 - val_loss: 0.0044
# Epoch 42/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 6.8247e-04 - val_loss: 0.0044
# Epoch 43/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 6.8457e-04 - val_loss: 0.0042
# Epoch 44/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 6.7267e-04 - val_loss: 0.0040
# Epoch 45/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 6.4576e-04 - val_loss: 0.0042
# Epoch 46/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 6.2667e-04 - val_loss: 0.0043
# Epoch 00046: early stopping

# %%
#Loss Visualization for data training and validation

plt.figure(figsize=(15,10))
plt.plot(model_train.history['loss'])
plt.plot(model_train.history['val_loss'])
plt.title('Model Performance')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Validation'], loc='upper right')
plt.show()

# %%
result = model.predict(train_X)

# %%
train_y.shape
# Out:
# (497, 1)

# %%
result.shape
# Out:
# (497, 1)

# %%
#Invert Scalled Value into Actual Value

result = scalerMinMax.inverse_transform(result.reshape(-1,1))
train_y = scalerMinMax.inverse_transform(train_y.reshape(-1,1))

# %%
#Flatten the Data

result = result.flatten()
train_y = train_y.flatten()

# %%
#Check the RMSE and MAE (Training Process)

rmse_train = np.sqrt(mean_squared_error(train_y, result))
print('Train Root Mean Squared Error:', rmse_train)

mae_train = (mean_absolute_error(train_y, result))
print('Train Mean Absolute Error:', mae_train)
# Out:
# Train Root Mean Squared Error: 42.095443054050904
# Train Mean Absolute Error: 29.362567317788283

# %%
#Make the length date -4
data_train = data_train[4:]
data_test = data_test[4:]

# %%
#Visuzalize the Predicted Result and Actual Data Train

plt.figure(figsize=(20,10))
plt.title("Training Predicted Price")
plt.xlabel('Date')
plt.ylabel('Price')
plt.plot(data_train['Date'],result)
plt.plot(data_train['Date'],train_y)
plt.legend(['True','Predict'], loc='upper right')
plt.show()

# %% [markdown]
# ## Testing

# %%
#Testing
predicted_result = model.predict(test_X, verbose=0)

# %%
#Invert Scalled Value into Actual Value
predicted_result = scalerMinMax.inverse_transform(predicted_result.reshape(-1,1))
test_y = scalerMinMax.inverse_transform(test_y.reshape(-1,1))

# %%
#Flatten the Data

predicted_result = predicted_result.flatten()
test_y = test_y.flatten()

# %%
#Check the RMSE and MAE (Testing Process)

rmse = np.sqrt(mean_squared_error(test_y, predicted_result))
print('Test Root Mean Squared Error:', rmse)

mae = (mean_absolute_error(test_y, predicted_result))
print('Test Mean Absolute Error:', mae)
# Out:
# Test Root Mean Squared Error: 46.29048575376231
# Test Mean Absolute Error: 34.74100045868844

# %%
#Visuzalize the Predicted Result and Actual Data Test

plt.figure(figsize=(20,10))
plt.title("Predicted Price")
plt.xlabel('Date')
plt.ylabel('Price')
plt.plot(data_test['Date'], predicted_result)
plt.plot(data_test['Date'], test_y)
plt.legend(['True','Predict'], loc='upper right')
plt.show()
